# %%
import numpy as np
import pandas as pd
import pyarrow.parquet as pq
import plotly.graph_objects as go
import matplotlib.pylab as plt
from astropy.time import Time
from time import time


from multiprocessing import Process
import os

# print(f"{np.__name__} --> version {np.__version__}")
# print(f"{pa.__name__} --> version {pa.__version__}")
# !python -c "import numpy as xx; print(f'{xx.__name__} \t--> version {xx.__version__}')"
# !python -c "import pyarrow as xx; print(f'{xx.__name__} --> version {xx.__version__}')"
# !python -c "import plotly as xx; print(f'{xx.__name__} \t--> version {xx.__version__}')"
# !python -c "import astropy as xx; print(f'{xx.__name__} --> version {xx.__version__}')"
# Out:
# numpy 	--> version 1.22.4
# pyarrow --> version 9.0.0
# plotly 	--> version 5.10.0
# astropy --> version 5.1

# %%
cores = os.cpu_count()
print(f'numero de nucleos',cores)
# Out:
# numero de nucleos 12

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Universidad/Trabajo de Titulo/Modelos ML curvas de luz

# %cd /content/drive/MyDrive/Universidad/Trabajo de Titulo/Modelos ML curvas de luz#Aca va tu ruta del archivo en tu drive
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\Leonardo Peña\Documents\Github\HistogramasAdaptativos\Light curve with adaptative histograms.ipynb Celda 3 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Leonardo%20Pe%C3%B1a/Documents/Github/HistogramasAdaptativos/Light%20curve%20with%20adaptative%20histograms.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> from google.colab import drive
#       <a href='vscode-notebook-cell:/c%3A/Users/Leonardo%20Pe%C3%B1a/Documents/Github/HistogramasAdaptativos/Light%20curve%20with%20adaptative%20histograms.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> drive.mount('/content/drive')
#       <a href='vscode-notebook-cell:/c%3A/Users/Leonardo%20Pe%C3%B1a/Documents/Github/HistogramasAdaptativos/Light%20curve%20with%20adaptative%20histograms.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a> get_ipython().run_line_magic('cd', '/content/drive/MyDrive/Universidad/Trabajo de Titulo/Modelos ML curvas de luz')
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
def getStatistic(index,indBin,magnitud, amount_bins):
    #Analisis en base a la magnitud
    mag_ordered = magnitud[index]
    # print('mag index',index)
    # print('mag',mag_ordered)
    #Obtención de vectores con caracteristicas estadisticas
    
    vector_mean = np.array([np.nanmean(mag_ordered[indBin==(i+1)])  if (indBin==(i+1)).sum()>0 else -1000  for i in range(amount_bins)])
    vector_max = np.array([np.nanmax(mag_ordered[indBin==(i+1)])  if (indBin==(i+1)).sum()>0 else -1000 for i in range(amount_bins)])
    vector_min = np.array([np.nanmin(mag_ordered[indBin==(i+1)])  if (indBin==(i+1)).sum()>0 else -1000 for i in range(amount_bins)])
    vector_std = np.array([np.nanstd(mag_ordered[indBin==(i+1)])  if (indBin==(i+1)).sum()>0 else -1000 for i in range(amount_bins)])

    # mean_process = Process(target=np.array([np.nanmean(mag_ordered[indBin==(i+1)])  if (indBin==(i+1)).sum()>0 else -1000  for i in range(amount_bins)]))
    # max_process = Process(target=np.array([np.nanmax(mag_ordered[indBin==(i+1)])  if (indBin==(i+1)).sum()>0 else -1000 for i in range(amount_bins)]))
    # min_process = Process(target=np.array([np.nanmin(mag_ordered[indBin==(i+1)])  if (indBin==(i+1)).sum()>0 else -1000 for i in range(amount_bins)]))
    # std_process = Process(target=np.array([np.nanstd(mag_ordered[indBin==(i+1)])  if (indBin==(i+1)).sum()>0 else -1000 for i in range(amount_bins)]))

    #start multiprocessing 
    # mean_process.start()
    # max_process.start()
    # min_process.start()
    # std_process.start()

    # get data
    # vector_mean = mean_process.join()
    # vector_max = max_process.join()
    # vector_min = min_process.join()
    # vector_std = std_process.join()
    # return [vector_mean,vector_max,vector_min,vector_std]
    return [vector_mean,vector_max,vector_min,vector_std]

    

def drawGraphic(bins,time,mag,indice,period):
    title_figure = f'Folded Time Serie with period T/{period}'
    #Grafico para ver la serie de tiempo 
    plt.figure(figsize=(12,4))
    plt.plot(time[indice], mag[indice])
    plt.scatter(time[indice], mag[indice])
    plt.ylabel("Magnitud")
    plt.xlabel("Time")
    plt.suptitle(title_figure, fontsize=22)
    plt.grid(axis='x', color='red', linestyle='-', linewidth=2)

    for bin in bins:
        plt.axvline(x=bin,color='red')
    # plt.grid(axis='y', color='gray', linestyle='dashed')
    plt.show()


def variantion_period_v2(array_periods,ts_time, ts_mag, amount_bins=10):
    tensor_data = []
    for period in array_periods:
        #valor del periodo en decimales
        period_float = 1 / period
        #proceso de folding
        folded_time = ts_time % period_float
        # print('folded_time',folded_time)

        #indices de los datos para encontrarlos luego del folding
        index_folded = np.argsort(folded_time)
        # print('index_folded',index_folded)

        #Divido el periodo en bins o intervalos [0,n] para luego obtener datos estadisticos de cada bin
        bins = np.linspace(0,period_float,amount_bins+1)
        #Concentración de datos en cada bin
        concentration, bin_edges= np.histogram(folded_time[index_folded],bins=bins)
        #indices - Devuelve los índices de los bins a los que pertenece cada valor del folded_time
        index_bin = np.digitize(folded_time[index_folded],bins=bins)

        # print("bins: ",bins)
        # print("concentracion de datos en cada bin: ",concentration)
        #Obtención de datos estadisticos de cada bin y formación del tensor
        vectorStatisticPeriod = np.asmatrix(getStatistic(index_folded,index_bin,ts_mag,amount_bins))
        tensor_data.append(vectorStatisticPeriod)

    return tensor_data

# funcion para graficar la serie de tiempo con link al sitio web de ALeRCE del evento
def GraphicLightCurve(fig,band,light_curve,show):
    mtcolor = [['g','green'],['r','red'],['b','blue']]
    idx=(light_curve['fid']==band).values
    fig.add_trace(
            go.Scatter(
                x = light_curve.mjd.values[idx],
                y = light_curve.magpsf_corr.values[idx],
                mode = 'markers', name=mtcolor[band-1][0],
                marker_color = mtcolor[band-1][1],
                error_y = dict(type='data', array=light_curve.sigmapsf_corr.values[idx], visible=True),
                marker = dict(size=10, opacity=0.5, showscale=False, line=dict(width=1)), 
                showlegend = True,
                legendgroup = mtcolor[band-1][0],
                hovertemplate ='<b>' + mtcolor[band-1][0] + ':\t\t</b>' + light_curve.magpsf_corr[idx].map('{:.3f}'.format).apply(str) + ' ± ' +
                                light_curve.sigmapsf_corr[idx].map('{:.3f}'.format).apply(str)  + '<br>' + 
                                '<b>MJD:\t</b>'+ light_curve.mjd[idx].apply(str)  + '<br>' + 
                                '<b>Date:\t</b>'+ [temp.strftime('%a, %d %b %Y %H:%M:%S UTC') for temp in Time(light_curve.mjd[idx].values, format='mjd').datetime]+ '<br>' +
                                '<extra></extra>'
                ))
    # fig['layout']['yaxis']['autorange'] = "reversed"
    fig.update_xaxes(
        tickangle=0,
        title_text="Modified Julian Dates [MJD]",
        title_font={"size": 14})
    
    fig.update_yaxes(
        autorange= 'reversed',
        tickangle=0,
        title_text="Magnitude [Mag]",
        title_font={"size": 14})
    
    fig.update_layout(
        title={'text':'<b>Light Curve</b>' + '<br>' +
                        '<a href="https://alerce.online/object/'+ event + '">Object: ' + event + 'text</a>',
                'font':dict(size=14),'x':0.5, 'y':0.9,'xanchor': 'center','yanchor': 'top'})
    
    if_show_fig = lambda show: fig.show() if show == True else False
    if_show_fig(show)

# %%
parquet_file = pq.ParquetFile('../lightcurves_ts.parquet')
# parquet_file.schema_arrow.names # obtienes nombre columnas
# parquet_file.metadata.num_rows # numero de filas
# parquet_file.metadata.num_columns # nummero de columnas 

print("numero de columnas:", parquet_file.metadata.num_columns)
print("numero de filas (datos): ", parquet_file.metadata.num_rows)
# print("nombre columnas: ", parquet_file.schema_arrow.names)
# Out:
# numero de columnas: 113
# numero de filas (datos):  13844917

# %%
# Descipcion de las columnas
# oid -- object id
# fid -- filter id, filtro o banda utilizada (verde,rojo,azul,etc)
# mjd -- medida de tiempo continua (Modified Julian date / Calendario Juliano Modificado)
# magpsf_corr -- magnitud psf correjida / posicion en el espacio, es el promedio de los pixeles de una deteccion
# sigmapsf_corr -- variacion de los pixeles de una deteccion
# nbad -- numero de bandas
# classALeRCE - clasificación que realiza ALeRCE en base a los parametros obtenidos (152 aprox) con el random forest de 2 niveles



# se divide el paquete en grupos --> se ocupa el primer grupo 0
data = parquet_file.read_row_group(0, ['oid', 'fid', 'mjd', 'magpsf_corr', 'sigmapsf_corr', 'classALeRCE']).to_pandas()
# data.shape
# data.head(50)

# %%
data.shape
# type(data)
# print("numero de filas (datos): ", data)

data.head()
# Out:
#             oid  fid           mjd  magpsf_corr  sigmapsf_corr classALeRCE
# 0  ZTF17aaacfxu    1  58863.138021    20.996371       0.444790         RRL
# 1  ZTF17aaacfxu    1  58867.179803    19.374605       0.175861         RRL
# 2  ZTF17aaacfxu    1  58871.170336    19.630466       0.123111         RRL
# 3  ZTF17aaacfxu    1  58880.146204    19.362001       0.103466         RRL
# 4  ZTF17aaacfxu    1  58849.131389    19.530453       0.078387         RRL

# %%
# muestra los eventos unicos, sin repeticiones
all_event = data.oid.unique()
# all_event

print('eventos totales',all_event.shape)
# Out:
# eventos totales (173693,)

# %% [markdown]
# Probando cosas

# %%
# data.head()

# limpieza de datos 
df_data = data.replace([np.inf, -np.inf], np.nan)
df_data = df_data.dropna()
df_data.head()


print(df_data['classALeRCE'].values.size)
df_data.head()
# Out:
# 13697564
#             oid  fid           mjd  magpsf_corr  sigmapsf_corr classALeRCE
# 0  ZTF17aaacfxu    1  58863.138021    20.996371       0.444790         RRL
# 1  ZTF17aaacfxu    1  58867.179803    19.374605       0.175861         RRL
# 2  ZTF17aaacfxu    1  58871.170336    19.630466       0.123111         RRL
# 3  ZTF17aaacfxu    1  58880.146204    19.362001       0.103466         RRL
# 4  ZTF17aaacfxu    1  58849.131389    19.530453       0.078387         RRL

# %%
df_data_unique = df_data.oid.unique()

# ------

limit = 10
num_periods = 4
nbines = 10
array_periods = 2**(np.arange(num_periods)+0)

# ------
# tensor_all_event = []

time_arr = []

i = 0

# %%
all_time_serie = []

for index, name_event in enumerate(df_data_unique):
    event = df_data.loc[df_data['oid'] == name_event].sort_values(by=['mjd'])
    rows_event, cols_event = event.shape

    if(rows_event == 1):
        continue

    all_time_serie.append(event)
    i = i + 1

    if i == limit:
        break

print(len(all_time_serie))
# Out:
# 10

# %%
dict_all_tensor = {}

main_start = time()
limit_event = 10
for index, event in enumerate(all_time_serie):
    # print(index,event)
    name_unique = event.oid.unique()
    # print(index,name_unique)

    dict_tensor = {}

    for band_fid in range(1,4):
        event_band = event.loc[event['fid'] == band_fid].sort_values(by=['mjd'])
        
        # print(event_band['oid'])
        if(event_band.empty is False):
            rows, cols = event_band.shape

            if(rows == 1):
                break

            # normalized
            min_mjd = event_band['mjd'].values.min()
            max_mjd = event_band['mjd'].values.max()
            time_normalized = (event_band['mjd'].values - min_mjd)/(max_mjd - min_mjd)

            # get tensor with features
            tensor = np.array(variantion_period_v2(array_periods, time_normalized, event_band['magpsf_corr'].values, nbines))
            
            # tensor_all_band.append(tensor)
            dict_tensor[f'Filter {band_fid}'] = tensor
        else:
            break
    # print('-'*50)
    dict_all_tensor[f'{name_unique}'] = dict_tensor
    

    if index == limit_event:
        break

print('-'*100)
main_time = time() - main_start
print(f'Time total: {main_time}')
print(f'Total event: {limit_event}')
# print(dict_all_tensor)

# print(f'Mean Time for each event: {np.mean(time_arr)}')
# Out:
# ----------------------------------------------------------------------------------------------------
# Time total: 0.10770583152770996
# Total event: 10

# %%
import json
from json import JSONEncoder


class NumpyArrayEncoder(JSONEncoder):
    def default(self, obj):
        if isinstance(obj, np.ndarray):
            return obj.tolist()
        return JSONEncoder.default(self, obj)

test = json.dumps(dict_all_tensor, cls=NumpyArrayEncoder)

with open('group0.json', 'w') as outfile:
    outfile.write(test)

# %% [markdown]
# fin test

# %%
main_start = time()

for index, name_event in enumerate(all_time_serie):
    event_start = time()
    dict_tensor = {}
    # tensor_all_band = []
    # event = df_data.loc[df_data['oid'] == name_event].sort_values(by=['mjd'])
    rows_event, cols_event = event.shape

    if(rows_event == 1):
        continue

    print(f'Event n {index}: {name_event} with {rows_event} x {cols_event}')
    # for each band
    for band_fid in range(1,4):
        event_band = event.loc[event['fid'] == band_fid].sort_values(by=['mjd'])
        if(event_band.empty is False):
            rows, cols = event_band.shape

            if(rows == 1):
                break

            # normalized
            min_mjd = event_band['mjd'].values.min()
            max_mjd = event_band['mjd'].values.max()
            time_normalized = (event_band['mjd'].values - min_mjd)/(max_mjd - min_mjd)

            # get tensor with features
            tensor = np.array(variantion_period_v2(array_periods, time_normalized, event_band['magpsf_corr'].values, nbines))
            
            # tensor_all_band.append(tensor)
            dict_tensor[f'Filter {band_fid}'] = tensor
        else:
            break

    dict_all_tensor[f'{name_event}'] = dict_tensor
    # tensor_all_band = np.array(tensor_all_band)
    # tensor_all_event.append(tensor_all_band)
    # time
    event_time = time() - event_start
    time_arr.append(event_time)
    i = i + 1

    if i == limit:
        break

# %%
df_data_unique = df_data.oid.unique()

# ------

limit = 1000
num_periods = 4
nbines = 10
array_periods = 2**(np.arange(num_periods)+0)

# ------

dict_all_tensor = {}
tensor_all_event = []
main_start = time()

time_arr = []

i = 0
for index, name_event in enumerate(df_data_unique):
    event_start = time()
    dict_tensor = {}
    tensor_all_band = []
    event = df_data.loc[df_data['oid'] == name_event].sort_values(by=['mjd'])
    rows_event, cols_event = event.shape

    if(rows_event == 1):
        continue

    print(f'Event n {index}: {name_event} with {rows_event} x {cols_event}')
    # for each band
    for band_fid in range(1,4):
        event_band = event.loc[event['fid'] == band_fid].sort_values(by=['mjd'])
        if(event_band.empty is False):
            rows, cols = event_band.shape

            if(rows == 1):
                break

            # normalized
            min_mjd = event_band['mjd'].values.min()
            max_mjd = event_band['mjd'].values.max()
            time_normalized = (event_band['mjd'].values - min_mjd)/(max_mjd - min_mjd)

            # get tensor with features
            tensor = np.array(variantion_period_v2(array_periods, time_normalized, event_band['magpsf_corr'].values, nbines))
            
            tensor_all_band.append(tensor)
            dict_tensor[f'Filter {band_fid}'] = tensor
        else:
            break

    dict_all_tensor[f'{name_event}'] = dict_tensor
    tensor_all_band = np.array(tensor_all_band)
    tensor_all_event.append(tensor_all_band)
    # time
    event_time = time() - event_start
    time_arr.append(event_time)
    i = i + 1

    if i == limit:
        break

print('-'*100)
main_time = time() - main_start
print(f'Time total: {main_time}')
print(f'Total event: {i}')
print(f'Mean Time for each event: {np.mean(time_arr)}')
# Out:
# Event n 0: ZTF17aaacfxu with 5 x 7
# Event n 2: ZTF17aaaemke with 88 x 7
# Event n 3: ZTF17aaafyya with 372 x 7
# Event n 4: ZTF17aaageae with 217 x 7
# Event n 5: ZTF17aaaivsr with 79 x 7
# Event n 6: ZTF17aaaizej with 100 x 7
# Event n 7: ZTF17aaajizt with 52 x 7
# Event n 8: ZTF17aaajlul with 135 x 7
# Event n 9: ZTF17aaakstv with 87 x 7
# Event n 10: ZTF17aaanxog with 45 x 7
# Event n 11: ZTF17aaanyaa with 108 x 7
# Event n 12: ZTF17aaapkds with 104 x 7
# Event n 13: ZTF17aaaptuh with 36 x 7
# Event n 14: ZTF17aaaselv with 137 x 7
# Event n 15: ZTF17aaasfod with 152 x 7
# Event n 16: ZTF17aaatvll with 96 x 7
# Event n 17: ZTF17aaawcrw with 561 x 7
# Event n 18: ZTF17aaawcwz with 161 x 7
# Event n 19: ZTF17aaawmqu with 93 x 7
# Event n 20: ZTF17aaawthq with 55 x 7
# Event n 21: ZTF17aaawwnd with 114 x 7
# Event n 22: ZTF17aabdxyc with 164 x 7
# Event n 23: ZTF17aabiewn with 36 x 7
# Event n 24: ZTF17aabkwrk with 37 x 7
# Event n 25: ZTF17aabmdav with 111 x 7
# Event n 26: ZTF17aaboajb with 39 x 7
# Event n 27: ZTF17aabofis with 199 x 7
# Event n 28: ZTF17aabofpf with 92 x 7
# Event n 29: ZTF17aabsvct with 72 x 7
# Event n 30: ZTF17aabszwz with 162 x 7
# Event n 31: ZTF17aabudqo with 152 x 7
# Event n 32: ZTF17aabunuc with 198 x 7
# Event n 33: ZTF17aabutbe with 213 x 7
# Event n 34: ZTF17aabuulj with 375 x 7
# Event n 35: ZTF17aabvhhm with 38 x 7
# Event n 36: ZTF17aabwcjm with 145 x 7
# Event n 37: ZTF17aabwdvq with 27 x 7
# Event n 38: ZTF17aabwjmc with 43 x 7
# Event n 39: ZTF17aabwjrz with 82 x 7
# Event n 40: ZTF17aabwrne with 164 x 7
# Event n 41: ZTF17aabwxmu with 155 x 7
# Event n 42: ZTF17aabxwne with 80 x 7
# Event n 43: ZTF17aacempk with 132 x 7
# Event n 44: ZTF17aacngys with 313 x 7
# Event n 45: ZTF17aacnscd with 91 x 7
# Event n 46: ZTF17aacpjzx with 131 x 7
# Event n 47: ZTF17aacxsqt with 45 x 7
# Event n 48: ZTF17aadddmp with 245 x 7
# Event n 49: ZTF18aaaagoy with 58 x 7
# Event n 50: ZTF18aaaauqs with 123 x 7
# Event n 51: ZTF18aaabcbk with 126 x 7
# Event n 52: ZTF18aaackau with 89 x 7
# Event n 53: ZTF18aaacmdt with 314 x 7
# Event n 54: ZTF18aaacucv with 134 x 7
# Event n 55: ZTF18aaacxlg with 159 x 7
# Event n 56: ZTF18aaacxpf with 187 x 7
# Event n 57: ZTF18aaadhha with 184 x 7
# Event n 58: ZTF18aaadogp with 99 x 7
# Event n 59: ZTF18aaadsbj with 199 x 7
# Event n 60: ZTF18aaadtgh with 213 x 7
# Event n 61: ZTF18aaadxvl with 168 x 7
# Event n 62: ZTF18aaagojp with 129 x 7
# Event n 63: ZTF18aaagwrb with 33 x 7
# Event n 64: ZTF18aaaiezw with 149 x 7
# Event n 65: ZTF18aaaiygf with 159 x 7
# Event n 66: ZTF18aaalpdf with 95 x 7
# Event n 68: ZTF18aaaomtu with 111 x 7
# Event n 69: ZTF18aaapdpk with 22 x 7
# Event n 70: ZTF18aaapozs with 108 x 7
# Event n 72: ZTF18aaaxfoq with 4 x 7
# Event n 73: ZTF18aaaxsra with 62 x 7
# Event n 74: ZTF18aabadjg with 2 x 7
# Event n 75: ZTF18aabcchi with 9 x 7
# Event n 76: ZTF18aabeokc with 187 x 7
# Event n 77: ZTF18aabetde with 156 x 7
# Event n 78: ZTF18aabexxx with 80 x 7
# Event n 79: ZTF18aabfqrb with 265 x 7
# Event n 80: ZTF18aabfuoq with 82 x 7
# Event n 81: ZTF18aabiuei with 74 x 7
# Event n 82: ZTF18aabnjdp with 4 x 7
# Event n 83: ZTF18aabtufv with 179 x 7
# Event n 85: ZTF18aachpte with 4 x 7
# Event n 86: ZTF18aadgrkd with 5 x 7
# Event n 87: ZTF18aaeeabc with 42 x 7
# Event n 88: ZTF18aaerxdd with 28 x 7
# Event n 89: ZTF18aaevxhj with 55 x 7
# Event n 90: ZTF18aafdnsq with 39 x 7
# Event n 91: ZTF18aagrcyg with 110 x 7
# Event n 92: ZTF18aagrgcs with 37 x 7
# Event n 93: ZTF18aagrggn with 372 x 7
# Event n 94: ZTF18aagrhuq with 229 x 7
# Event n 95: ZTF18aagszxm with 580 x 7
# Event n 96: ZTF18aagteml with 77 x 7
# Event n 97: ZTF18aagtgix with 529 x 7
# Event n 98: ZTF18aahewru with 105 x 7
# Event n 99: ZTF18aahojki with 14 x 7
# Event n 100: ZTF18aahqepx with 135 x 7
# Event n 101: ZTF18aahrhsm with 11 x 7
# Event n 102: ZTF18aaiivhs with 68 x 7
# Event n 103: ZTF18aaiiwap with 49 x 7
# Event n 105: ZTF18aaiwjop with 211 x 7
# Event n 106: ZTF18aaixazr with 280 x 7
# Event n 107: ZTF18aaixvtj with 121 x 7
# Event n 108: ZTF18aajbitw with 99 x 7
# Event n 109: ZTF18aajcmau with 46 x 7
# Event n 110: ZTF18aajedfg with 68 x 7
# Event n 111: ZTF18aajhrvr with 12 x 7
# Event n 112: ZTF18aajqrmp with 300 x 7
# Event n 113: ZTF18aajqtge with 289 x 7
# Event n 114: ZTF18aajtwnn with 104 x 7
# Event n 115: ZTF18aajxvan with 24 x 7
# Event n 116: ZTF18aakbxxv with 162 x 7
# Event n 117: ZTF18aakgfuy with 61 x 7
# Event n 118: ZTF18aaknkyt with 2 x 7
# Event n 119: ZTF18aakzhat with 347 x 7
# Event n 120: ZTF18aalamwe with 185 x 7
# Event n 121: ZTF18aammpcj with 84 x 7
# Event n 122: ZTF18aamndyk with 129 x 7
# Event n 123: ZTF18aaowinw with 5 x 7
# Event n 124: ZTF18aaptchy with 189 x 7
# Event n 125: ZTF18aapuheo with 41 x 7
# Event n 126: ZTF18aaqeqwd with 283 x 7
# Event n 128: ZTF18aascbfw with 68 x 7
# Event n 129: ZTF18aascqlw with 7 x 7
# Event n 130: ZTF18aashcfs with 106 x 7
# Event n 131: ZTF18aasouef with 21 x 7
# Event n 132: ZTF18aauipis with 9 x 7
# Event n 133: ZTF18aaukrps with 102 x 7
# Event n 134: ZTF18aauksml with 2 x 7
# Event n 135: ZTF18aauwmxy with 57 x 7
# Event n 136: ZTF18aauxnti with 79 x 7
# Event n 137: ZTF18aavscmw with 48 x 7
# Event n 138: ZTF18aavucmo with 340 x 7
# Event n 139: ZTF18aavyouk with 284 x 7
# Event n 140: ZTF18aawagmg with 68 x 7
# Event n 141: ZTF18aawqlqh with 96 x 7
# Event n 142: ZTF18aawrmou with 290 x 7
# Event n 143: ZTF18aaxmnla with 159 x 7
# Event n 144: ZTF18aaxmrni with 146 x 7
# Event n 145: ZTF18aaxsazi with 161 x 7
# Event n 146: ZTF18aaxyxkq with 113 x 7
# Event n 147: ZTF18aaxyymz with 240 x 7
# Event n 148: ZTF18aaxzgzl with 43 x 7
# Event n 149: ZTF18aayetrm with 295 x 7
# Event n 150: ZTF18aayjwjk with 161 x 7
# Event n 151: ZTF18aaywrsm with 374 x 7
# Event n 152: ZTF18aazelrt with 662 x 7
# Event n 153: ZTF18aazfecb with 301 x 7
# Event n 155: ZTF18aazrohc with 74 x 7
# Event n 156: ZTF18aazuqua with 222 x 7
# Event n 157: ZTF18abadltc with 486 x 7
# Event n 158: ZTF18abaelqq with 76 x 7
# Event n 159: ZTF18abafdst with 189 x 7
# Event n 160: ZTF18abafrlr with 92 x 7
# Event n 161: ZTF18abahdyl with 14 x 7
# Event n 162: ZTF18abaivke with 41 x 7
# Event n 163: ZTF18abasctf with 180 x 7
# Event n 164: ZTF18abastwo with 151 x 7
# Event n 165: ZTF18abatwdh with 9 x 7
# Event n 166: ZTF18abayblu with 99 x 7
# Event n 167: ZTF18abbelwa with 237 x 7
# Event n 168: ZTF18abbemat with 241 x 7
# Event n 169: ZTF18abbkgjp with 31 x 7
# Event n 170: ZTF18abbpxse with 98 x 7
# Event n 171: ZTF18abbwgmv with 205 x 7
# Event n 172: ZTF18abbwswk with 38 x 7
# Event n 173: ZTF18abcedgy with 64 x 7
# Event n 174: ZTF18abcjzfe with 419 x 7
# Event n 175: ZTF18abckocd with 220 x 7
# Event n 176: ZTF18abcoxqk with 24 x 7
# Event n 177: ZTF18abcphec with 444 x 7
# Event n 178: ZTF18abcpokm with 81 x 7
# Event n 179: ZTF18abcpviv with 285 x 7
# Event n 180: ZTF18abctbgx with 118 x 7
# Event n 181: ZTF18abcvlym with 245 x 7
# Event n 182: ZTF18abcwdph with 131 x 7
# Event n 183: ZTF18abcxutn with 53 x 7
# Event n 184: ZTF18abcyzue with 323 x 7
# Event n 185: ZTF18abczeek with 247 x 7
# Event n 186: ZTF18abdbjhh with 35 x 7
# Event n 187: ZTF18abddmuf with 96 x 7
# Event n 188: ZTF18abddohm with 53 x 7
# Event n 189: ZTF18abdeyfg with 154 x 7
# Event n 190: ZTF18abdeygm with 157 x 7
# Event n 191: ZTF18abdxymh with 25 x 7
# Event n 192: ZTF18abebfrs with 137 x 7
# Event n 193: ZTF18abecywu with 196 x 7
# Event n 194: ZTF18abefhat with 14 x 7
# Event n 195: ZTF18abefwuw with 47 x 7
# Event n 196: ZTF18abegfbs with 52 x 7
# Event n 197: ZTF18abehjlj with 108 x 7
# Event n 198: ZTF18abeifex with 221 x 7
# Event n 199: ZTF18abejcac with 38 x 7
# Event n 200: ZTF18abekuol with 26 x 7
# Event n 201: ZTF18abesmxc with 281 x 7
# Event n 202: ZTF18abeweoi with 17 x 7
# Event n 203: ZTF18abfxghg with 149 x 7
# Event n 204: ZTF18abgjslm with 57 x 7
# Event n 205: ZTF18abgsqtv with 95 x 7
# Event n 206: ZTF18abgvgre with 15 x 7
# Event n 207: ZTF18abgvzke with 34 x 7
# Event n 208: ZTF18abhozks with 98 x 7
# Event n 209: ZTF18abhtyyn with 32 x 7
# Event n 210: ZTF18abhxigv with 45 x 7
# Event n 211: ZTF18abigult with 239 x 7
# Event n 212: ZTF18abikitj with 198 x 7
# Event n 213: ZTF18abjlial with 15 x 7
# Event n 214: ZTF18abjtkav with 129 x 7
# Event n 215: ZTF18abjydcn with 72 x 7
# Event n 216: ZTF18abkeqmm with 70 x 7
# Event n 218: ZTF18abkwpdu with 99 x 7
# Event n 219: ZTF18ablhpqi with 157 x 7
# Event n 220: ZTF18ablqdor with 81 x 7
# Event n 221: ZTF18ablqmoq with 17 x 7
# Event n 222: ZTF18ablrpet with 75 x 7
# Event n 223: ZTF18abmagur with 212 x 7
# Event n 224: ZTF18abmahyd with 148 x 7
# Event n 225: ZTF18abmascw with 181 x 7
# Event n 226: ZTF18abmekhq with 425 x 7
# Event n 227: ZTF18abmfmjk with 99 x 7
# Event n 229: ZTF18abmotqd with 67 x 7
# Event n 230: ZTF18abmouki with 38 x 7
# Event n 231: ZTF18abmplye with 118 x 7
# Event n 232: ZTF18abmrrru with 198 x 7
# Event n 233: ZTF18abmvhty with 40 x 7
# Event n 234: ZTF18abmvqyr with 151 x 7
# Event n 235: ZTF18abmvrdy with 9 x 7
# Event n 236: ZTF18abncigk with 194 x 7
# Event n 237: ZTF18abnjsor with 21 x 7
# Event n 238: ZTF18abnnbgq with 57 x 7
# Event n 239: ZTF18abnoqky with 19 x 7
# Event n 240: ZTF18abnttng with 48 x 7
# Event n 241: ZTF18abnuepj with 110 x 7
# Event n 242: ZTF18abnufhw with 13 x 7
# Event n 243: ZTF18abnuoqf with 41 x 7
# Event n 244: ZTF18abnyhes with 102 x 7
# Event n 245: ZTF18aboacia with 10 x 7
# Event n 246: ZTF18aboacki with 22 x 7
# Event n 247: ZTF18abobios with 99 x 7
# Event n 248: ZTF18abojnkw with 53 x 7
# Event n 249: ZTF18aboluur with 26 x 7
# Event n 250: ZTF18abolvpm with 48 x 7
# Event n 251: ZTF18aboqzgd with 4 x 7
# Event n 252: ZTF18aborxfa with 117 x 7
# Event n 253: ZTF18abotaqw with 13 x 7
# Event n 254: ZTF18abotfhz with 170 x 7
# Event n 255: ZTF18abpcvjz with 50 x 7
# Event n 256: ZTF18abpfecf with 67 x 7
# Event n 257: ZTF18abpyasr with 8 x 7
# Event n 258: ZTF18abpybto with 2 x 7
# Event n 259: ZTF18abqvoxq with 32 x 7
# Event n 260: ZTF18abqxupq with 175 x 7
# Event n 261: ZTF18abrymgp with 71 x 7
# Event n 262: ZTF18abscggk with 106 x 7
# Event n 263: ZTF18absdudu with 141 x 7
# Event n 264: ZTF18absggfa with 48 x 7
# Event n 265: ZTF18absgjkq with 37 x 7
# Event n 266: ZTF18abshgtz with 277 x 7
# Event n 267: ZTF18abshzqv with 3 x 7
# Event n 268: ZTF18absjcpm with 2 x 7
# Event n 269: ZTF18abskdst with 13 x 7
# Event n 270: ZTF18abskrdb with 36 x 7
# Event n 271: ZTF18absqivk with 49 x 7
# Event n 272: ZTF18abstbck with 49 x 7
# Event n 273: ZTF18absuten with 36 x 7
# Event n 274: ZTF18absutup with 97 x 7
# Event n 275: ZTF18abtdoey with 30 x 7
# Event n 276: ZTF18abtjjyf with 180 x 7
# Event n 277: ZTF18abtmwjn with 184 x 7
# Event n 278: ZTF18abtrdrf with 112 x 7
# Event n 279: ZTF18abtrvxi with 81 x 7
# Event n 280: ZTF18abttpjs with 108 x 7
# Event n 281: ZTF18abtvgqs with 59 x 7
# Event n 282: ZTF18abtyuyp with 16 x 7
# Event n 283: ZTF18abtzzsw with 50 x 7
# Event n 284: ZTF18abudvit with 66 x 7
# Event n 285: ZTF18abudwkb with 49 x 7
# Event n 286: ZTF18abufumo with 66 x 7
# Event n 287: ZTF18abuizyd with 83 x 7
# Event n 288: ZTF18abukteg with 49 x 7
# Event n 289: ZTF18abuncpy with 158 x 7
# Event n 290: ZTF18abusecb with 36 x 7
# Event n 291: ZTF18abutaex with 133 x 7
# Event n 292: ZTF18abutrfq with 67 x 7
# Event n 293: ZTF18abuyhup with 36 x 7
# Event n 294: ZTF18abvbcbm with 73 x 7
# Event n 295: ZTF18abvbdsu with 54 x 7
# Event n 296: ZTF18abvbocf with 68 x 7
# Event n 297: ZTF18abviwkr with 112 x 7
# Event n 299: ZTF18abvldku with 42 x 7
# Event n 300: ZTF18abvmtsy with 39 x 7
# Event n 301: ZTF18abvpojy with 67 x 7
# Event n 302: ZTF18abvtdzm with 18 x 7
# Event n 303: ZTF18abvtipg with 79 x 7
# Event n 304: ZTF18abvwpwl with 15 x 7
# Event n 305: ZTF18abwbopw with 7 x 7
# Event n 306: ZTF18abwklir with 270 x 7
# Event n 307: ZTF18abwnmcu with 57 x 7
# Event n 308: ZTF18abwtlkp with 22 x 7
# Event n 309: ZTF18abxbbfp with 165 x 7
# Event n 310: ZTF18abxbdgw with 7 x 7
# Event n 311: ZTF18abxilbb with 103 x 7
# Event n 312: ZTF18abxkckr with 129 x 7
# Event n 313: ZTF18abybwfh with 299 x 7
# Event n 314: ZTF18abycphv with 42 x 7
# Event n 315: ZTF18abzpdkq with 19 x 7
# Event n 316: ZTF18acaksce with 57 x 7
# Event n 317: ZTF18acavjfi with 76 x 7
# Event n 318: ZTF18acavoik with 50 x 7
# Event n 319: ZTF18acaywol with 44 x 7
# Event n 320: ZTF18acbujwf with 26 x 7
# Event n 321: ZTF18acbyibu with 24 x 7
# Event n 322: ZTF18accdeht with 11 x 7
# Event n 323: ZTF18acckqvx with 29 x 7
# Event n 324: ZTF18acclino with 154 x 7
# Event n 325: ZTF18accvycz with 96 x 7
# Event n 326: ZTF18accwiuq with 77 x 7
# Event n 327: ZTF18acdvqku with 74 x 7
# Event n 328: ZTF18acdwbft with 94 x 7
# Event n 329: ZTF18acdwgki with 5 x 7
# Event n 330: ZTF18acebjus with 45 x 7
# Event n 331: ZTF18aceezaa with 30 x 7
# Event n 332: ZTF18acehmol with 124 x 7
# Event n 333: ZTF18aceikhp with 74 x 7
# Event n 334: ZTF18aceinlm with 6 x 7
# Event n 335: ZTF18acelnre with 22 x 7
# Event n 336: ZTF18aceqzfu with 30 x 7
# Event n 337: ZTF18acerlpm with 30 x 7
# Event n 338: ZTF18acewlyu with 37 x 7
# Event n 339: ZTF18acewujh with 28 x 7
# Event n 340: ZTF18acezmjz with 7 x 7
# Event n 341: ZTF18acfpalr with 95 x 7
# Event n 342: ZTF18acgmccq with 77 x 7
# Event n 343: ZTF18acgpwio with 73 x 7
# Event n 345: ZTF18acibeqd with 17 x 7
# Event n 346: ZTF18acmyxil with 20 x 7
# Event n 347: ZTF18acnbepp with 5 x 7
# Event n 348: ZTF18acnmerj with 103 x 7
# Event n 349: ZTF18acpdeos with 73 x 7
# Event n 350: ZTF18acpdwsd with 2 x 7
# Event n 351: ZTF18acprsya with 23 x 7
# Event n 352: ZTF18acqsqcd with 67 x 7
# Event n 353: ZTF18acqzhtp with 55 x 7
# Event n 354: ZTF18acrgxwd with 4 x 7
# Event n 355: ZTF18acrnimn with 22 x 7
# Event n 356: ZTF18acrungd with 30 x 7
# Event n 357: ZTF18acrygmx with 37 x 7
# Event n 358: ZTF18acsbbup with 124 x 7
# Event n 359: ZTF18acsiggs with 98 x 7
# Event n 360: ZTF18acskhgs with 20 x 7
# Event n 362: ZTF18acsosvh with 80 x 7
# Event n 363: ZTF18acsovmi with 24 x 7
# Event n 364: ZTF18actxgvf with 25 x 7
# Event n 365: ZTF18acuemsf with 310 x 7
# Event n 366: ZTF18acuenec with 46 x 7
# Event n 367: ZTF18acueucb with 119 x 7
# Event n 368: ZTF18aculorx with 18 x 7
# Event n 369: ZTF18acvhure with 76 x 7
# Event n 370: ZTF18acvvpon with 43 x 7
# Event n 371: ZTF18acvvyau with 70 x 7
# Event n 372: ZTF18acvvykn with 38 x 7
# Event n 373: ZTF18acvwauz with 28 x 7
# Event n 374: ZTF18acwyqdm with 169 x 7
# Event n 375: ZTF18acwyumn with 158 x 7
# Event n 376: ZTF18acwyxty with 9 x 7
# Event n 377: ZTF18acwzasl with 45 x 7
# Event n 378: ZTF18acxzjsh with 76 x 7
# Event n 379: ZTF18aczerfr with 115 x 7
# Event n 380: ZTF18aczesze with 65 x 7
# Event n 381: ZTF18aczexyr with 41 x 7
# Event n 382: ZTF18aczfiht with 6 x 7
# Event n 383: ZTF18aczopyv with 18 x 7
# Event n 384: ZTF18aczrrxp with 32 x 7
# Event n 385: ZTF18adasgea with 29 x 7
# Event n 386: ZTF18adatoel with 12 x 7
# Event n 387: ZTF18adaziki with 52 x 7
# Event n 388: ZTF18adazuse with 5 x 7
# Event n 390: ZTF18adbltnm with 24 x 7
# Event n 391: ZTF18adbnasn with 61 x 7
# Event n 392: ZTF18adbuohh with 2 x 7
# Event n 393: ZTF18adcayfr with 28 x 7
# Event n 394: ZTF18adfjsiw with 4 x 7
# Event n 395: ZTF19aaaeahy with 26 x 7
# Event n 396: ZTF19aaailrw with 20 x 7
# Event n 397: ZTF19aaakxvl with 23 x 7
# Event n 398: ZTF19aaapmbd with 96 x 7
# Event n 399: ZTF19aabfrlc with 16 x 7
# Event n 400: ZTF19aabzvpd with 76 x 7
# Event n 401: ZTF19aacitmo with 3 x 7
# Event n 402: ZTF19aackymy with 29 x 7
# Event n 403: ZTF19aacqfol with 51 x 7
# Event n 404: ZTF19aadaedp with 44 x 7
# Event n 405: ZTF19aadgpmh with 29 x 7
# Event n 406: ZTF19aadgwpc with 115 x 7
# Event n 407: ZTF19aadhdqt with 5 x 7
# Event n 408: ZTF19aadlirl with 32 x 7
# Event n 409: ZTF19aadlzzh with 55 x 7
# Event n 410: ZTF19aadormf with 75 x 7
# Event n 411: ZTF19aaemhoc with 3 x 7
# Event n 413: ZTF19aaipueg with 54 x 7
# Event n 414: ZTF19aajwkbb with 11 x 7
# Event n 415: ZTF19aaknvuh with 48 x 7
# Event n 416: ZTF19aakrowk with 21 x 7
# Event n 417: ZTF19aalbcjt with 33 x 7
# Event n 418: ZTF19aalfcfs with 153 x 7
# Event n 419: ZTF19aalfpjj with 38 x 7
# Event n 420: ZTF19aaljkvv with 9 x 7
# Event n 421: ZTF19aalzwgd with 7 x 7
# Event n 422: ZTF19aamhbme with 8 x 7
# Event n 424: ZTF19aammuma with 4 x 7
# Event n 426: ZTF19aamnubo with 16 x 7
# Event n 427: ZTF19aamozya with 18 x 7
# Event n 429: ZTF19aamwsnq with 29 x 7
# Event n 430: ZTF19aanevrw with 10 x 7
# Event n 431: ZTF19aannrmo with 21 x 7
# Event n 432: ZTF19aanogch with 21 x 7
# Event n 433: ZTF19aanwsez with 51 x 7
# Event n 434: ZTF19aanxppa with 153 x 7
# Event n 435: ZTF19aaobwhu with 7 x 7
# Event n 436: ZTF19aaodzqh with 32 x 7
# Event n 437: ZTF19aaozsjc with 110 x 7
# Event n 438: ZTF19aapalil with 5 x 7
# Event n 439: ZTF19aapkrqp with 7 x 7
# Event n 440: ZTF19aaprour with 20 x 7
# Event n 441: ZTF19aapvogv with 11 x 7
# Event n 442: ZTF19aapwxwv with 13 x 7
# Event n 443: ZTF19aardosg with 36 x 7
# Event n 444: ZTF19aarfrpo with 2 x 7
# Event n 445: ZTF19aargvqm with 31 x 7
# Event n 446: ZTF19aasbaqy with 137 x 7
# Event n 447: ZTF19aasgowd with 17 x 7
# Event n 448: ZTF19aaskjoo with 9 x 7
# Event n 450: ZTF19aatnfmy with 8 x 7
# Event n 451: ZTF19aattawe with 28 x 7
# Event n 452: ZTF19aauethb with 9 x 7
# Event n 453: ZTF19aaugzmn with 2 x 7
# Event n 454: ZTF19aaujnth with 11 x 7
# Event n 455: ZTF19aaumlit with 50 x 7
# Event n 457: ZTF19aavojgt with 5 x 7
# Event n 458: ZTF19aavprkx with 79 x 7
# Event n 459: ZTF19aawsbtt with 8 x 7
# Event n 460: ZTF19aaxrncq with 24 x 7
# Event n 461: ZTF19aaxtxtb with 20 x 7
# Event n 462: ZTF19aaxtypl with 11 x 7
# Event n 463: ZTF19aaydqnt with 14 x 7
# Event n 464: ZTF19aayhrnb with 34 x 7
# Event n 465: ZTF19aayljdw with 34 x 7
# Event n 467: ZTF19aayrjcu with 30 x 7
# Event n 468: ZTF19aayxzvt with 15 x 7
# Event n 469: ZTF19aazloha with 37 x 7
# Event n 470: ZTF19aazpnqj with 246 x 7
# Event n 471: ZTF19abbwlax with 45 x 7
# Event n 472: ZTF19abcgdkr with 11 x 7
# Event n 473: ZTF19abcnlpp with 10 x 7
# Event n 474: ZTF19abdyywy with 51 x 7
# Event n 475: ZTF19abegmrd with 43 x 7
# Event n 476: ZTF19abeyxtz with 77 x 7
# Event n 477: ZTF19abfiqah with 64 x 7
# Event n 478: ZTF19abfqlih with 12 x 7
# Event n 480: ZTF19abhfgry with 3 x 7
# Event n 481: ZTF19abhgrpa with 3 x 7
# Event n 483: ZTF19abjplnh with 27 x 7
# Event n 484: ZTF19abjswdz with 4 x 7
# Event n 485: ZTF19abqgxze with 70 x 7
# Event n 486: ZTF19abqstat with 28 x 7
# Event n 487: ZTF19abqwakm with 45 x 7
# Event n 488: ZTF19abrrhsr with 133 x 7
# Event n 489: ZTF19abuxfqt with 25 x 7
# Event n 490: ZTF19abvflof with 23 x 7
# Event n 491: ZTF19abxgenk with 16 x 7
# Event n 492: ZTF19abztrlv with 7 x 7
# Event n 493: ZTF19acaheep with 87 x 7
# Event n 494: ZTF19acasgse with 7 x 7
# Event n 495: ZTF19acbjnei with 120 x 7
# Event n 496: ZTF19aceilwt with 6 x 7
# Event n 497: ZTF19aceofdv with 3 x 7
# Event n 498: ZTF19acfxbki with 6 x 7
# Event n 500: ZTF19achvzlv with 3 x 7
# Event n 501: ZTF19acifuyf with 14 x 7
# Event n 502: ZTF19acigeac with 8 x 7
# Event n 504: ZTF19aclqxzm with 20 x 7
# Event n 505: ZTF19acmbgug with 27 x 7
# Event n 506: ZTF19acnyjtb with 12 x 7
# Event n 507: ZTF19actvtvr with 6 x 7
# Event n 508: ZTF19acuaqef with 7 x 7
# Event n 509: ZTF19acvghzz with 43 x 7
# Event n 510: ZTF19acvixxc with 6 x 7
# Event n 511: ZTF19acvtxaw with 2 x 7
# Event n 512: ZTF19acymgpq with 42 x 7
# Event n 513: ZTF19acyxvme with 5 x 7
# Event n 514: ZTF19adcchbp with 2 x 7
# Event n 515: ZTF19adccmdp with 9 x 7
# Event n 516: ZTF19adceqlt with 14 x 7
# Event n 517: ZTF19adcfnbt with 70 x 7
# Event n 518: ZTF19adcfnyc with 25 x 7
# Event n 519: ZTF19adcfowp with 23 x 7
# Event n 520: ZTF19adcfrvn with 11 x 7
# Event n 522: ZTF19adcfvpg with 38 x 7
# Event n 523: ZTF20aaaxhjp with 2 x 7
# Event n 524: ZTF20aacxkyj with 14 x 7
# Event n 525: ZTF20aacyjou with 10 x 7
# Event n 526: ZTF20aacyvzk with 20 x 7
# Event n 527: ZTF20aadclze with 39 x 7
# Event n 528: ZTF20aadvasi with 7 x 7
# Event n 529: ZTF20aadvqkb with 4 x 7
# Event n 530: ZTF20aaebbtp with 7 x 7
# Event n 531: ZTF20aaeibqo with 41 x 7
# Event n 532: ZTF20aafdsba with 8 x 7
# Event n 533: ZTF20aahcxez with 10 x 7
# Event n 534: ZTF20aahfnbz with 12 x 7
# Event n 535: ZTF20aahhurh with 2 x 7
# Event n 536: ZTF20aahqbpq with 25 x 7
# Event n 537: ZTF20aaicdhx with 8 x 7
# Event n 538: ZTF20aaieubj with 43 x 7
# Event n 539: ZTF20aaifsey with 57 x 7
# Event n 540: ZTF20aaisczp with 6 x 7
# Event n 541: ZTF20aajveoa with 12 x 7
# Event n 542: ZTF20aakjkko with 6 x 7
# Event n 544: ZTF20aakkvbm with 2 x 7
# Event n 545: ZTF20aaljupo with 32 x 7
# Event n 546: ZTF20aalrlpi with 5 x 7
# Event n 547: ZTF20aalrnnl with 46 x 7
# Event n 548: ZTF20aandgck with 26 x 7
# Event n 549: ZTF20aanhloz with 21 x 7
# Event n 550: ZTF20aaockhe with 7 x 7
# Event n 551: ZTF20aapcoxv with 12 x 7
# Event n 552: ZTF20aapnacw with 10 x 7
# Event n 553: ZTF20aapndzj with 14 x 7
# Event n 554: ZTF20aapojsa with 10 x 7
# Event n 555: ZTF20aaqhstf with 8 x 7
# Event n 556: ZTF20aarscwt with 56 x 7
# Event n 557: ZTF20aarxsej with 2 x 7
# Event n 559: ZTF20aatqbhv with 17 x 7
# Event n 561: ZTF20aavokfu with 3 x 7
# Event n 564: ZTF20aavxphg with 23 x 7
# Event n 565: ZTF20aavyzwt with 30 x 7
# Event n 566: ZTF20aavzfzv with 9 x 7
# Event n 567: ZTF20aawabos with 5 x 7
# Event n 568: ZTF20aawagxa with 7 x 7
# Event n 569: ZTF20aawlwfx with 19 x 7
# Event n 570: ZTF20aaxcthi with 18 x 7
# Event n 571: ZTF20aaxvvcz with 2 x 7
# Event n 572: ZTF20aazfvln with 12 x 7
# Event n 573: ZTF20aazhezm with 4 x 7
# Event n 574: ZTF20abbhldq with 4 x 7
# Event n 575: ZTF20abchqmp with 17 x 7
# Event n 577: ZTF20abcuwbw with 5 x 7
# Event n 578: ZTF20abcvgvo with 6 x 7
# Event n 579: ZTF20abftdme with 3 x 7
# Event n 580: ZTF17aaadosl with 100 x 7
# Event n 581: ZTF17aaagyfr with 31 x 7
# Event n 582: ZTF17aaaiatx with 20 x 7
# Event n 583: ZTF17aaaieeq with 136 x 7
# Event n 584: ZTF17aaaiyyp with 96 x 7
# Event n 585: ZTF17aaakpay with 94 x 7
# Event n 586: ZTF17aaanwwp with 177 x 7
# Event n 587: ZTF17aaarsfe with 187 x 7
# Event n 588: ZTF17aaaskum with 153 x 7
# Event n 589: ZTF17aabcwge with 40 x 7
# Event n 590: ZTF17aabhlpx with 201 x 7
# Event n 591: ZTF17aabqpzh with 86 x 7
# Event n 592: ZTF17aabsipk with 237 x 7
# Event n 593: ZTF17aabuklr with 170 x 7
# Event n 594: ZTF17aabukyt with 594 x 7
# Event n 595: ZTF17aabulab with 222 x 7
# Event n 596: ZTF17aaburqu with 255 x 7
# Event n 597: ZTF17aabvbcv with 144 x 7
# Event n 598: ZTF17aabwlxe with 77 x 7
# Event n 599: ZTF17aabxofq with 160 x 7
# Event n 600: ZTF17aabxqyw with 36 x 7
# Event n 601: ZTF17aacfelz with 46 x 7
# Event n 602: ZTF17aackvns with 112 x 7
# Event n 603: ZTF17aadjwjp with 90 x 7
# Event n 604: ZTF17aadkrxy with 118 x 7
# Event n 605: ZTF17aadlybn with 41 x 7
# Event n 606: ZTF17aadsniz with 85 x 7
# Event n 607: ZTF18aaaaaes with 51 x 7
# Event n 608: ZTF18aaaakzz with 176 x 7
# Event n 609: ZTF18aaaatck with 146 x 7
# Event n 610: ZTF18aaacutj with 190 x 7
# Event n 611: ZTF18aaacyii with 108 x 7
# Event n 612: ZTF18aaadlhq with 53 x 7
# Event n 613: ZTF18aaadwci with 180 x 7
# Event n 614: ZTF18aaadwxx with 186 x 7
# Event n 615: ZTF18aaafupp with 84 x 7
# Event n 616: ZTF18aaagbui with 147 x 7
# Event n 617: ZTF18aaahoks with 212 x 7
# Event n 618: ZTF18aaaoxli with 136 x 7
# Event n 619: ZTF18aaauiyu with 109 x 7
# Event n 620: ZTF18aaauvyi with 95 x 7
# Event n 621: ZTF18aaawgfo with 3 x 7
# Event n 622: ZTF18aaaxsbz with 70 x 7
# Event n 623: ZTF18aabdres with 45 x 7
# Event n 624: ZTF18aabggww with 368 x 7
# Event n 625: ZTF18aabgivg with 50 x 7
# Event n 626: ZTF18aabgzcc with 64 x 7
# Event n 627: ZTF18aabhadu with 144 x 7
# Event n 628: ZTF18aabhldo with 84 x 7
# Event n 629: ZTF18aabhmjq with 94 x 7
# Event n 630: ZTF18aabhxtz with 78 x 7
# Event n 631: ZTF18aabirqt with 96 x 7
# Event n 632: ZTF18aabjihf with 178 x 7
# Event n 633: ZTF18aabkngc with 64 x 7
# Event n 634: ZTF18aablakb with 185 x 7
# Event n 635: ZTF18aabltdz with 9 x 7
# Event n 638: ZTF18aabqvqp with 151 x 7
# Event n 639: ZTF18aacipxo with 58 x 7
# Event n 640: ZTF18aactiia with 76 x 7
# Event n 641: ZTF18aadgdhy with 17 x 7
# Event n 643: ZTF18aafbrrj with 39 x 7
# Event n 644: ZTF18aafmkoz with 14 x 7
# Event n 645: ZTF18aagrfnl with 236 x 7
# Event n 646: ZTF18aaholem with 49 x 7
# Event n 647: ZTF18aahotkv with 25 x 7
# Event n 648: ZTF18aaigpfu with 301 x 7
# Event n 649: ZTF18aaijcei with 40 x 7
# Event n 650: ZTF18aaikalw with 130 x 7
# Event n 651: ZTF18aaimvkw with 353 x 7
# Event n 652: ZTF18aaipvwu with 14 x 7
# Event n 653: ZTF18aaixqgx with 211 x 7
# Event n 654: ZTF18aaixwpa with 36 x 7
# Event n 655: ZTF18aajbohk with 258 x 7
# Event n 656: ZTF18aajcksu with 130 x 7
# Event n 657: ZTF18aajhwtl with 5 x 7
# Event n 658: ZTF18aajrwsz with 139 x 7
# Event n 659: ZTF18aajtlfl with 263 x 7
# Event n 660: ZTF18aaksunj with 67 x 7
# Event n 661: ZTF18aakxpdk with 321 x 7
# Event n 662: ZTF18aamiine with 317 x 7
# Event n 663: ZTF18aammoxe with 169 x 7
# Event n 664: ZTF18aanguyh with 145 x 7
# Event n 665: ZTF18aanvtie with 439 x 7
# Event n 667: ZTF18aaqqzpe with 21 x 7
# Event n 668: ZTF18aarllza with 22 x 7
# Event n 669: ZTF18aarmxjn with 186 x 7
# Event n 670: ZTF18aasxpyg with 25 x 7
# Event n 671: ZTF18aasyimg with 27 x 7
# Event n 672: ZTF18aatxbnc with 37 x 7
# Event n 673: ZTF18aaumcfp with 34 x 7
# Event n 674: ZTF18aavjavy with 12 x 7
# Event n 675: ZTF18aavskqq with 86 x 7
# Event n 676: ZTF18aavzoke with 232 x 7
# Event n 677: ZTF18aawfedc with 54 x 7
# Event n 678: ZTF18aawfhtw with 39 x 7
# Event n 679: ZTF18aawtohm with 60 x 7
# Event n 680: ZTF18aawzlil with 68 x 7
# Event n 681: ZTF18aaxczbv with 217 x 7
# Event n 682: ZTF18aaxjdvf with 136 x 7
# Event n 683: ZTF18aaxrbve with 5 x 7
# Event n 684: ZTF18aaxumbs with 331 x 7
# Event n 685: ZTF18aaxwkyi with 100 x 7
# Event n 686: ZTF18aaydkga with 320 x 7
# Event n 687: ZTF18aayfbcn with 432 x 7
# Event n 688: ZTF18aaykmkz with 21 x 7
# Event n 689: ZTF18aaykois with 16 x 7
# Event n 690: ZTF18aaylsvt with 28 x 7
# Event n 691: ZTF18aaynrvg with 271 x 7
# Event n 692: ZTF18aaznddr with 119 x 7
# Event n 693: ZTF18aazzvev with 20 x 7
# Event n 694: ZTF18abachcm with 70 x 7
# Event n 695: ZTF18abafawu with 77 x 7
# Event n 696: ZTF18abajwwr with 106 x 7
# Event n 697: ZTF18abamjry with 134 x 7
# Event n 698: ZTF18abaqwpc with 232 x 7
# Event n 699: ZTF18abashpu with 406 x 7
# Event n 700: ZTF18abbkghl with 110 x 7
# Event n 701: ZTF18abbkkrw with 150 x 7
# Event n 702: ZTF18abblrcz with 255 x 7
# Event n 703: ZTF18abcddao with 102 x 7
# Event n 704: ZTF18abcgmkv with 140 x 7
# Event n 705: ZTF18abcgxgv with 266 x 7
# Event n 706: ZTF18abchhqp with 248 x 7
# Event n 707: ZTF18abckioq with 326 x 7
# Event n 708: ZTF18abckpdy with 499 x 7
# Event n 709: ZTF18abclbal with 59 x 7
# Event n 710: ZTF18abcllqp with 68 x 7
# Event n 711: ZTF18abcodcx with 92 x 7
# Event n 712: ZTF18abcscbr with 80 x 7
# Event n 713: ZTF18abcsgna with 2 x 7
# Event n 714: ZTF18abcvqrn with 9 x 7
# Event n 715: ZTF18abcwala with 429 x 7
# Event n 716: ZTF18abcwxtn with 142 x 7
# Event n 718: ZTF18abdcolc with 13 x 7
# Event n 719: ZTF18abdegib with 166 x 7
# Event n 720: ZTF18abdeyov with 286 x 7
# Event n 721: ZTF18abdjxax with 415 x 7
# Event n 722: ZTF18abdlhoy with 87 x 7
# Event n 723: ZTF18abdnyyv with 214 x 7
# Event n 724: ZTF18abdqbaq with 25 x 7
# Event n 725: ZTF18abdsazw with 29 x 7
# Event n 726: ZTF18abduhof with 23 x 7
# Event n 727: ZTF18abeaapa with 124 x 7
# Event n 728: ZTF18abebodz with 209 x 7
# Event n 729: ZTF18abebxhw with 245 x 7
# Event n 730: ZTF18abehfhv with 100 x 7
# Event n 731: ZTF18abehjkg with 86 x 7
# Event n 732: ZTF18abejtng with 180 x 7
# Event n 733: ZTF18abestog with 196 x 7
# Event n 734: ZTF18abetiux with 37 x 7
# Event n 735: ZTF18abfptyu with 18 x 7
# Event n 736: ZTF18abfrkgw with 185 x 7
# Event n 737: ZTF18abfxgkj with 155 x 7
# Event n 738: ZTF18abgithq with 245 x 7
# Event n 739: ZTF18abgyilg with 9 x 7
# Event n 740: ZTF18abgyjae with 290 x 7
# Event n 741: ZTF18abihwnb with 44 x 7
# Event n 742: ZTF18abikbxc with 77 x 7
# Event n 743: ZTF18abiliwt with 465 x 7
# Event n 744: ZTF18abiltxl with 354 x 7
# Event n 745: ZTF18abinela with 76 x 7
# Event n 746: ZTF18abinfdl with 59 x 7
# Event n 747: ZTF18abinfyc with 47 x 7
# Event n 748: ZTF18abiyddl with 100 x 7
# Event n 749: ZTF18abjgfkg with 37 x 7
# Event n 750: ZTF18abkeqik with 139 x 7
# Event n 751: ZTF18abkobvi with 70 x 7
# Event n 752: ZTF18ablihyd with 94 x 7
# Event n 753: ZTF18ablmiks with 70 x 7
# Event n 754: ZTF18ablqgfg with 45 x 7
# Event n 755: ZTF18ablqrmr with 174 x 7
# Event n 756: ZTF18ablwxwp with 131 x 7
# Event n 757: ZTF18abmagni with 44 x 7
# Event n 758: ZTF18abmagpb with 7 x 7
# Event n 759: ZTF18abmfmrz with 47 x 7
# Event n 760: ZTF18abmioqa with 200 x 7
# Event n 761: ZTF18abmjvfz with 90 x 7
# Event n 762: ZTF18abmofek with 24 x 7
# Event n 763: ZTF18abmotuu with 121 x 7
# Event n 764: ZTF18abmqudx with 63 x 7
# Event n 765: ZTF18abmvheu with 52 x 7
# Event n 766: ZTF18abmvnhz with 36 x 7
# Event n 767: ZTF18abmwdwi with 73 x 7
# Event n 768: ZTF18abmwsvb with 479 x 7
# Event n 769: ZTF18abnckjb with 77 x 7
# Event n 770: ZTF18abnfoyl with 13 x 7
# Event n 771: ZTF18abnjuat with 11 x 7
# Event n 772: ZTF18abnjuro with 55 x 7
# Event n 773: ZTF18abnmtvc with 61 x 7
# Event n 774: ZTF18abnodyg with 121 x 7
# Event n 775: ZTF18abnyhxn with 50 x 7
# Event n 776: ZTF18abnysyx with 32 x 7
# Event n 777: ZTF18abnyudr with 461 x 7
# Event n 778: ZTF18abobksj with 156 x 7
# Event n 779: ZTF18abobkya with 81 x 7
# Event n 780: ZTF18abodpzs with 28 x 7
# Event n 781: ZTF18abomakq with 68 x 7
# Event n 782: ZTF18aborsqp with 122 x 7
# Event n 783: ZTF18abosqyl with 109 x 7
# Event n 784: ZTF18aboyndj with 13 x 7
# Event n 785: ZTF18abpmwuc with 63 x 7
# Event n 786: ZTF18abppppg with 5 x 7
# Event n 787: ZTF18abqawhp with 54 x 7
# Event n 788: ZTF18abqvamg with 28 x 7
# Event n 789: ZTF18abqweiz with 13 x 7
# Event n 790: ZTF18abrdedy with 3 x 7
# Event n 791: ZTF18abrecxd with 70 x 7
# Event n 792: ZTF18abrnjow with 14 x 7
# Event n 793: ZTF18abrrnls with 181 x 7
# Event n 794: ZTF18abryrxy with 86 x 7
# Event n 795: ZTF18abrywam with 243 x 7
# Event n 796: ZTF18absggid with 3 x 7
# Event n 797: ZTF18abslfjq with 145 x 7
# Event n 798: ZTF18absnrlv with 125 x 7
# Event n 799: ZTF18absoofl with 199 x 7
# Event n 800: ZTF18absqgnq with 13 x 7
# Event n 801: ZTF18absqqlt with 175 x 7
# Event n 802: ZTF18absunky with 60 x 7
# Event n 803: ZTF18absuyax with 22 x 7
# Event n 804: ZTF18absvbfn with 92 x 7
# Event n 805: ZTF18abtfgcg with 260 x 7
# Event n 806: ZTF18abtlqxd with 78 x 7
# Event n 807: ZTF18abtsflm with 217 x 7
# Event n 808: ZTF18abttkfx with 7 x 7
# Event n 809: ZTF18abtvisj with 114 x 7
# Event n 810: ZTF18abtvjan with 69 x 7
# Event n 811: ZTF18abtwadr with 61 x 7
# Event n 812: ZTF18abtzatb with 86 x 7
# Event n 813: ZTF18abudvph with 73 x 7
# Event n 814: ZTF18abuiysi with 18 x 7
# Event n 815: ZTF18abuktsb with 178 x 7
# Event n 816: ZTF18abukzqn with 102 x 7
# Event n 817: ZTF18abupjuc with 83 x 7
# Event n 818: ZTF18abuvxai with 292 x 7
# Event n 819: ZTF18abvbgas with 101 x 7
# Event n 820: ZTF18abvemzi with 150 x 7
# Event n 821: ZTF18abvklaz with 147 x 7
# Event n 822: ZTF18abvmijd with 64 x 7
# Event n 823: ZTF18abvoxbz with 11 x 7
# Event n 824: ZTF18abvpipt with 14 x 7
# Event n 825: ZTF18abvtfpt with 32 x 7
# Event n 826: ZTF18abvtnrj with 68 x 7
# Event n 827: ZTF18abvvwou with 47 x 7
# Event n 828: ZTF18abvwsdu with 4 x 7
# Event n 829: ZTF18abwehwb with 100 x 7
# Event n 830: ZTF18abwkuxp with 44 x 7
# Event n 831: ZTF18abwlnro with 11 x 7
# Event n 833: ZTF18abwsgkf with 5 x 7
# Event n 834: ZTF18abxwidx with 6 x 7
# Event n 835: ZTF18abxyedf with 132 x 7
# Event n 836: ZTF18abyzmdf with 66 x 7
# Event n 837: ZTF18abzsdio with 64 x 7
# Event n 838: ZTF18acakaan with 295 x 7
# Event n 839: ZTF18acavhyn with 29 x 7
# Event n 840: ZTF18acawhzc with 55 x 7
# Event n 841: ZTF18acbwgfz with 37 x 7
# Event n 842: ZTF18acbxnex with 125 x 7
# Event n 843: ZTF18acbyvhb with 10 x 7
# Event n 844: ZTF18acbzlgr with 274 x 7
# Event n 845: ZTF18acbzlxj with 4 x 7
# Event n 846: ZTF18accdmxn with 11 x 7
# Event n 847: ZTF18accpjeb with 18 x 7
# Event n 848: ZTF18accqdcm with 28 x 7
# Event n 849: ZTF18acctbrp with 19 x 7
# Event n 850: ZTF18acctvzu with 42 x 7
# Event n 851: ZTF18acddxln with 2 x 7
# Event n 852: ZTF18acdvxtz with 193 x 7
# Event n 854: ZTF18acehkav with 150 x 7
# Event n 855: ZTF18acetkxy with 10 x 7
# Event n 856: ZTF18acexetj with 4 x 7
# Event n 857: ZTF18acfiwdo with 28 x 7
# Event n 858: ZTF18achckft with 35 x 7
# Event n 859: ZTF18achykqd with 37 x 7
# Event n 860: ZTF18achynei with 104 x 7
# Event n 861: ZTF18ackejmf with 7 x 7
# Event n 862: ZTF18acmcxqr with 50 x 7
# Event n 863: ZTF18acmfbfd with 115 x 7
# Event n 864: ZTF18acmfgst with 22 x 7
# Event n 865: ZTF18acnattc with 12 x 7
# Event n 866: ZTF18acnnyrf with 15 x 7
# Event n 867: ZTF18acpkfdc with 60 x 7
# Event n 868: ZTF18acpsuai with 60 x 7
# Event n 869: ZTF18acqlfbv with 18 x 7
# Event n 870: ZTF18acqslfp with 112 x 7
# Event n 871: ZTF18acqyorl with 36 x 7
# Event n 872: ZTF18acrmxyo with 8 x 7
# Event n 873: ZTF18acrulxr with 71 x 7
# Event n 874: ZTF18acrvcjl with 51 x 7
# Event n 875: ZTF18acrvcpv with 45 x 7
# Event n 876: ZTF18acrvqyr with 12 x 7
# Event n 877: ZTF18acrvsaz with 46 x 7
# Event n 878: ZTF18acrygvs with 88 x 7
# Event n 879: ZTF18acrygxo with 3 x 7
# Event n 880: ZTF18acszimn with 19 x 7
# Event n 881: ZTF18acszksy with 14 x 7
# Event n 882: ZTF18acszygy with 16 x 7
# Event n 883: ZTF18actabxv with 13 x 7
# Event n 884: ZTF18actavda with 47 x 7
# Event n 885: ZTF18actawir with 13 x 7
# Event n 887: ZTF18actzktj with 77 x 7
# Event n 888: ZTF18acullge with 3 x 7
# Event n 889: ZTF18aculsfq with 8 x 7
# Event n 890: ZTF18acuseom with 6 x 7
# Event n 891: ZTF18acussbu with 97 x 7
# Event n 892: ZTF18acvftix with 25 x 7
# Event n 893: ZTF18acvgwja with 134 x 7
# Event n 894: ZTF18acvrzup with 3 x 7
# Event n 895: ZTF18acvvyhs with 4 x 7
# Event n 896: ZTF18acvweqa with 12 x 7
# Event n 897: ZTF18acvwqeo with 62 x 7
# Event n 898: ZTF18acwynjq with 73 x 7
# Event n 899: ZTF18acwyynf with 25 x 7
# Event n 900: ZTF18acxxklc with 47 x 7
# Event n 901: ZTF18acxxqpr with 2 x 7
# Event n 902: ZTF18acydihz with 77 x 7
# Event n 903: ZTF18acyudjo with 5 x 7
# Event n 904: ZTF18acyvhhp with 27 x 7
# Event n 905: ZTF18acyvhim with 32 x 7
# Event n 906: ZTF18acyxuuh with 44 x 7
# Event n 907: ZTF18acyyecc with 29 x 7
# Event n 908: ZTF18aczerbf with 63 x 7
# Event n 909: ZTF18acztove with 13 x 7
# Event n 910: ZTF18aczuzqq with 3 x 7
# Event n 911: ZTF18aczvili with 2 x 7
# Event n 912: ZTF18adalcpx with 59 x 7
# Event n 913: ZTF18adaudsr with 27 x 7
# Event n 914: ZTF18adbahwx with 11 x 7
# Event n 915: ZTF18adbbvua with 5 x 7
# Event n 916: ZTF18adbbwjt with 44 x 7
# Event n 917: ZTF18adbhdqj with 94 x 7
# Event n 918: ZTF18adbiqbz with 76 x 7
# Event n 919: ZTF18adbyawk with 22 x 7
# Event n 920: ZTF18adgdnum with 57 x 7
# Event n 921: ZTF19aaafppr with 47 x 7
# Event n 922: ZTF19aaajacy with 22 x 7
# Event n 923: ZTF19aaakeaf with 30 x 7
# Event n 924: ZTF19aaaktnd with 78 x 7
# Event n 925: ZTF19aaakydh with 9 x 7
# Event n 926: ZTF19aaapjfd with 88 x 7
# Event n 927: ZTF19aaaqkbx with 66 x 7
# Event n 928: ZTF19aabkupz with 236 x 7
# Event n 929: ZTF19aabzggq with 117 x 7
# Event n 930: ZTF19aacugln with 7 x 7
# Event n 931: ZTF19aadeusj with 30 x 7
# Event n 933: ZTF19aadghmx with 5 x 7
# Event n 934: ZTF19aadgkaj with 25 x 7
# Event n 935: ZTF19aadhaop with 11 x 7
# Event n 936: ZTF19aadoqxc with 106 x 7
# Event n 937: ZTF19aadouwa with 70 x 7
# Event n 938: ZTF19aadyjgd with 17 x 7
# Event n 940: ZTF19aaepjzc with 45 x 7
# Event n 941: ZTF19aaeqflm with 70 x 7
# Event n 942: ZTF19aaeqkri with 7 x 7
# Event n 943: ZTF19aafaxer with 57 x 7
# Event n 944: ZTF19aafnpxr with 86 x 7
# Event n 945: ZTF19aagnqhu with 8 x 7
# Event n 946: ZTF19aahkvpi with 60 x 7
# Event n 947: ZTF19aaillls with 85 x 7
# Event n 948: ZTF19aailtfr with 74 x 7
# Event n 949: ZTF19aailtrj with 17 x 7
# Event n 950: ZTF19aailxjb with 3 x 7
# Event n 951: ZTF19aakljkk with 36 x 7
# Event n 952: ZTF19aakpjep with 12 x 7
# Event n 953: ZTF19aalamat with 68 x 7
# Event n 954: ZTF19aalbfoo with 20 x 7
# Event n 955: ZTF19aalbjdo with 61 x 7
# Event n 956: ZTF19aalbyrw with 130 x 7
# Event n 957: ZTF19aamoiaa with 6 x 7
# Event n 958: ZTF19aamvzrc with 12 x 7
# Event n 959: ZTF19aamvztt with 14 x 7
# Event n 960: ZTF19aanepmn with 5 x 7
# Event n 961: ZTF19aangrtt with 45 x 7
# Event n 962: ZTF19aanhhal with 45 x 7
# Event n 963: ZTF19aankded with 41 x 7
# Event n 964: ZTF19aankizn with 6 x 7
# Event n 965: ZTF19aanoujm with 5 x 7
# Event n 966: ZTF19aaoaqhp with 5 x 7
# Event n 967: ZTF19aaoeban with 2 x 7
# Event n 968: ZTF19aaoxyhe with 9 x 7
# Event n 969: ZTF19aapemkz with 3 x 7
# Event n 970: ZTF19aapkqyq with 7 x 7
# Event n 971: ZTF19aapryfs with 106 x 7
# Event n 972: ZTF19aapvqmg with 94 x 7
# Event n 973: ZTF19aaqbcmb with 37 x 7
# Event n 974: ZTF19aarffca with 11 x 7
# Event n 975: ZTF19aartult with 6 x 7
# Event n 976: ZTF19aarvbhn with 13 x 7
# Event n 977: ZTF19aarxpth with 22 x 7
# Event n 978: ZTF19aarziit with 14 x 7
# Event n 979: ZTF19aarziwp with 88 x 7
# Event n 980: ZTF19aasbmzw with 72 x 7
# Event n 981: ZTF19aasbnrv with 11 x 7
# Event n 982: ZTF19aascack with 29 x 7
# Event n 983: ZTF19aasckxc with 4 x 7
# Event n 984: ZTF19aascvyf with 28 x 7
# Event n 985: ZTF19aasedqn with 58 x 7
# Event n 986: ZTF19aasemog with 60 x 7
# Event n 987: ZTF19aaserof with 17 x 7
# Event n 988: ZTF19aasfdlm with 2 x 7
# Event n 989: ZTF19aasflpy with 19 x 7
# Event n 990: ZTF19aasgour with 6 x 7
# Event n 991: ZTF19aaskjip with 41 x 7
# Event n 992: ZTF19aaskjop with 2 x 7
# Event n 993: ZTF19aasktoa with 13 x 7
# Event n 994: ZTF19aaspqxs with 5 x 7
# Event n 995: ZTF19aatdsqp with 2 x 7
# Event n 996: ZTF19aathndo with 67 x 7
# Event n 997: ZTF19aatqdjz with 12 x 7
# Event n 998: ZTF19aatyrik with 8 x 7
# Event n 999: ZTF19aaueptf with 11 x 7
# Event n 1000: ZTF19aaukhcd with 31 x 7
# Event n 1001: ZTF19aauvfpg with 11 x 7
# Event n 1002: ZTF19aavrzvf with 63 x 7
# Event n 1003: ZTF19aavzqdd with 20 x 7
# Event n 1004: ZTF19aawfcya with 89 x 7
# Event n 1005: ZTF19aawocdq with 21 x 7
# Event n 1006: ZTF19aawodtk with 11 x 7
# Event n 1007: ZTF19aawrzvl with 15 x 7
# Event n 1008: ZTF19aawscli with 18 x 7
# Event n 1009: ZTF19aawzatw with 27 x 7
# Event n 1010: ZTF19aaxcawm with 56 x 7
# Event n 1011: ZTF19aaxkhkr with 27 x 7
# Event n 1012: ZTF19aaxrmjb with 25 x 7
# Event n 1013: ZTF19aaxrruk with 35 x 7
# Event n 1014: ZTF19aaxvprz with 31 x 7
# Event n 1015: ZTF19aaydjpk with 33 x 7
# Event n 1016: ZTF19aayhmwd with 28 x 7
# Event n 1017: ZTF19aayhrwi with 15 x 7
# Event n 1018: ZTF19aayliim with 29 x 7
# Event n 1019: ZTF19aaysahp with 23 x 7
# Event n 1020: ZTF19aayuodg with 13 x 7
# Event n 1021: ZTF19aazhnjs with 5 x 7
# Event n 1022: ZTF19aazlvsc with 59 x 7
# Event n 1023: ZTF19aazufqs with 21 x 7
# Event n 1024: ZTF19abcqcsr with 2 x 7
# Event n 1026: ZTF19abcuanw with 12 x 7
# Event n 1027: ZTF19abdbwgl with 29 x 7
# Event n 1028: ZTF19abdzltx with 2 x 7
# Event n 1029: ZTF19abfbaud with 13 x 7
# Event n 1030: ZTF19abgzcqj with 37 x 7
# Event n 1032: ZTF19abikdym with 11 x 7
# Event n 1033: ZTF19abikebo with 4 x 7
# Event n 1034: ZTF19abizyoy with 6 x 7
# Event n 1035: ZTF19abjadsb with 50 x 7
# Event n 1036: ZTF19abkekhy with 5 x 7
# Event n 1037: ZTF19abkfckn with 6 x 7
# Event n 1039: ZTF19ablesds with 35 x 7
# Event n 1040: ZTF19ablikyh with 2 x 7
# Event n 1041: ZTF19ablnkfc with 2 x 7
# Event n 1042: ZTF19ablopvv with 3 x 7
# Event n 1043: ZTF19abnaoao with 21 x 7
# ----------------------------------------------------------------------------------------------------
# Time total: 474.511577129364
# Total event: 1000
# Mean Time for each event: 0.45468404531478884

# %%
import json
from json import JSONEncoder


class NumpyArrayEncoder(JSONEncoder):
    def default(self, obj):
        if isinstance(obj, np.ndarray):
            return obj.tolist()
        return JSONEncoder.default(self, obj)

test = json.dumps(dict_all_tensor, cls=NumpyArrayEncoder)

with open('group0.json', 'w') as outfile:
    outfile.write(test)

# %% [markdown]
# END

# %% [markdown]
# --------------------------------------------
